# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sk
import copy
from collections import Counter
sns.set_style("whitegrid")

from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# %%
Cerebral_Stroke=pd.read_csv("dataset.csv")

# %% [markdown]
# # Data Preprocessing

# %%
Cerebral_Stroke
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0          children          Rural              95.12  18.0              NaN
# 1           Private          Urban              87.96  39.2     never smoked
# 2           Private          Urban             110.89  17.6              NaN
# 3           Private          Rural              69.04  35.9  formerly smoked
# 4      Never_worked          Rural             161.28  19.1              NaN
# ...             ...            ...                ...   ...              ...
# 43395      children          Urban              58.64  20.4     never smoked
# 43396      Govt_job          Urban             213.61  55.4  formerly smoked
# 43397       Private          Urban              91.94  28.9  formerly smoked
# 43398       Private          Urban              99.16  33.2     never smoked
# 43399       Private          Urban              79.48  20.6     never smoked
#
#        stroke
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 43395       0
# 43396       0
# 43397       0
# 43398       0
# 43399       0
#
# [43400 rows x 12 columns]

# %%
Cerebral_Stroke.describe(include='all')
# Out:
#                   id  gender           age  hypertension  heart_disease  \
# count   43400.000000   43400  43400.000000  43400.000000   43400.000000
# unique           NaN       3           NaN           NaN            NaN
# top              NaN  Female           NaN           NaN            NaN
# freq             NaN   25665           NaN           NaN            NaN
# mean    36326.142350     NaN     42.217894      0.093571       0.047512
# std     21072.134879     NaN     22.519649      0.291235       0.212733
# min         1.000000     NaN      0.080000      0.000000       0.000000
# 25%     18038.500000     NaN     24.000000      0.000000       0.000000
# 50%     36351.500000     NaN     44.000000      0.000000       0.000000
# 75%     54514.250000     NaN     60.000000      0.000000       0.000000
# max     72943.000000     NaN     82.000000      1.000000       1.000000
#
#        ever_married work_type Residence_type  avg_glucose_level           bmi  \
# count         43400     43400          43400       43400.000000  41938.000000
# unique            2         5              2                NaN           NaN
# top             Yes   Private          Urban                NaN           NaN
# freq          27938     24834          21756                NaN           NaN
# mean            NaN       NaN            NaN         104.482750     28.605038
# std             NaN       NaN            NaN          43.111751      7.770020
# min             NaN       NaN            NaN          55.000000     10.100000
# 25%             NaN       NaN            NaN          77.540000     23.200000
# 50%             NaN       NaN            NaN          91.580000     27.700000
# 75%             NaN       NaN            NaN         112.070000     32.900000
# max             NaN       NaN            NaN         291.050000     97.600000
#
#        smoking_status        stroke
# count           30108  43400.000000
# unique              3           NaN
# top      never smoked           NaN
# freq            16053           NaN
# mean              NaN      0.018041
# std               NaN      0.133103
# min               NaN      0.000000
# 25%               NaN      0.000000
# 50%               NaN      0.000000
# 75%               NaN      0.000000
# max               NaN      1.000000

# %%
Cerebral_Stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %%
Cerebral_Stroke.nunique()
# Out:
# id                   43400
# gender                   3
# age                    104
# hypertension             2
# heart_disease            2
# ever_married             2
# work_type                5
# Residence_type           2
# avg_glucose_level    12543
# bmi                    555
# smoking_status           3
# stroke                   2
# dtype: int64

# %%
#Calculating count of Stroke vs No Stroke cases
plt.figure(figsize=(5,5))
target_group = Cerebral_Stroke.groupby('stroke').size().reset_index()
pal = sns.color_palette("Greens_d", len(target_group))
rank = target_group["stroke"].argsort().argsort()
g = sns.barplot(x = target_group['stroke'],y = target_group[0],palette=np.array(pal[::-1])[rank] )

for index, row in target_group.iterrows():
    g.text(row['stroke'],row[0], round(row[0],2), color='black', ha="center",fontsize='x-large')

# %%
#Distribution of continuous 
Cerebral_Stroke.hist(figsize=(10,10))
plt.show()

# %%
#all the categorical columns with their values -
cols=Cerebral_Stroke.describe(include="O").columns
for i in cols:
    print("Distinct_values :\n 'column_name' =",i)
    print(Cerebral_Stroke[i].unique())
    print("")
# Out:
# Distinct_values :
#  'column_name' = gender
# ['Male' 'Female' 'Other']
#
# Distinct_values :
#  'column_name' = ever_married
# ['No' 'Yes']
#
# Distinct_values :
#  'column_name' = work_type
# ['children' 'Private' 'Never_worked' 'Self-employed' 'Govt_job']
#
# Distinct_values :
#  'column_name' = Residence_type
# ['Rural' 'Urban']
#
# Distinct_values :
#  'column_name' = smoking_status
# [nan 'never smoked' 'formerly smoked' 'smokes']

# %%
plt.figure(figsize=(16,4))
plt.subplot(121)
sns.countplot(Cerebral_Stroke["gender"],hue="stroke",data=Cerebral_Stroke,palette="Blues")
plt.title("gender",fontsize=15,color="Red")
plt.subplot(122)
sns.boxplot(x="bmi",y="gender",hue="stroke",data=Cerebral_Stroke,palette="Blues_r")
plt.title("GENDER vs BMI",fontsize=15,color="Red")
plt.figure(figsize=(16,4))
sns.scatterplot(Cerebral_Stroke["bmi"],Cerebral_Stroke["age"],hue=Cerebral_Stroke["stroke"])
plt.title("Distribution of Age Vs BMI : On basis of Stroke",fontsize=15,color="Red")
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(Cerebral_Stroke["work_type"],hue="stroke",data=Cerebral_Stroke,palette="RdPu_r")
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(Cerebral_Stroke["smoking_status"],hue="stroke",data=Cerebral_Stroke,palette="Accent")
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(Cerebral_Stroke["ever_married"],hue="stroke",data=Cerebral_Stroke,palette="Accent")
plt.show()

# %%
plt.figure(figsize=(13,4))
sns.countplot(Cerebral_Stroke["Residence_type"],hue="stroke",data=Cerebral_Stroke,palette="Accent")
plt.show()

# %%
sns.boxplot(Cerebral_Stroke["age"])
plt.show()

# %%
sns.boxplot(Cerebral_Stroke["avg_glucose_level"])
plt.show()

# %%
sns.boxplot(Cerebral_Stroke["bmi"])
plt.show()

# %%
plt.figure(figsize=(16,4))
sns.scatterplot(Cerebral_Stroke["avg_glucose_level"],Cerebral_Stroke["age"],hue=Cerebral_Stroke["stroke"])
plt.title("Distribution of Age Vs avg_glucose_level : On basis of Stroke",fontsize=15,color="Red")
plt.show()

# %%
#bmi and avg_glucose_level have outliers
plt.figure(figsize=(17,4))

plt.subplot(121)
res=stats.probplot(Cerebral_Stroke.bmi,plot=plt,dist="norm")
plt.xlabel("bmi",fontsize=16,color="m")

plt.subplot(122)
res=stats.probplot(Cerebral_Stroke.avg_glucose_level,plot=plt,dist="norm")
plt.xlabel("avg_glucose_level",fontsize=16,color="m")

plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(Cerebral_Stroke.corr(),cmap="Blues",annot=True,fmt='.2f')
plt.show()

# %%
#removing values those are greater then 60
Cerebral_Stroke=Cerebral_Stroke[Cerebral_Stroke['bmi'] < 60]

# %%
plt.figure(figsize=(17,4))

plt.subplot(121)
sns.boxplot(Cerebral_Stroke.bmi)

plt.subplot(122)
res=stats.probplot(Cerebral_Stroke.bmi,plot=plt,dist="norm")

# %%
#removing values those are greater then 270
Cerebral_Stroke=Cerebral_Stroke[Cerebral_Stroke['avg_glucose_level'] < 270]

# %%
plt.figure(figsize=(17,4))

plt.subplot(121)
sns.boxplot(Cerebral_Stroke.avg_glucose_level)

plt.subplot(122)
res=stats.probplot(Cerebral_Stroke.avg_glucose_level,plot=plt,dist="norm")

# %%
numerical_columns=['age','hypertension','heart_disease','avg_glucose_level','bmi']

# %% [markdown]
# #### imputing missing values

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan,
                        strategy ='mean')
Cerebral_Stroke[numerical_columns]=imputer.fit_transform(Cerebral_Stroke[numerical_columns])

# %%
column=Cerebral_Stroke['smoking_status'].values.reshape(-1,1)
column.shape
# Out:
# (41836, 1)

# %%
imputer = SimpleImputer(missing_values = np.nan,
                        strategy ='most_frequent')
Cerebral_Stroke['smoking_status']=imputer.fit_transform(column)

# %%
Cerebral_Stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41836 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 41836 non-null  int64
#  1   gender             41836 non-null  object
#  2   age                41836 non-null  float64
#  3   hypertension       41836 non-null  float64
#  4   heart_disease      41836 non-null  float64
#  5   ever_married       41836 non-null  object
#  6   work_type          41836 non-null  object
#  7   Residence_type     41836 non-null  object
#  8   avg_glucose_level  41836 non-null  float64
#  9   bmi                41836 non-null  float64
#  10  smoking_status     41836 non-null  object
#  11  stroke             41836 non-null  int64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 4.1+ MB

# %%
Cerebral_Stroke.drop(columns={"id"},inplace=True,axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labels=["gender","ever_married","work_type","Residence_type","smoking_status"]
label=LabelEncoder()

for i in labels:
    Cerebral_Stroke[i]=label.fit_transform(Cerebral_Stroke[i])

# %%
#dataset after using LabelEncoder
Cerebral_Stroke
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0           1   3.0           0.0            0.0             0          4
# 1           1  58.0           1.0            0.0             1          2
# 2           0   8.0           0.0            0.0             0          2
# 3           0  70.0           0.0            0.0             1          2
# 4           1  14.0           0.0            0.0             0          1
# ...       ...   ...           ...            ...           ...        ...
# 43395       0  10.0           0.0            0.0             0          4
# 43396       0  56.0           0.0            0.0             1          0
# 43397       0  82.0           1.0            0.0             1          2
# 43398       1  40.0           0.0            0.0             1          2
# 43399       0  82.0           0.0            0.0             1          2
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                   0              95.12  18.0               1       0
# 1                   1              87.96  39.2               1       0
# 2                   1             110.89  17.6               1       0
# 3                   0              69.04  35.9               0       0
# 4                   0             161.28  19.1               1       0
# ...               ...                ...   ...             ...     ...
# 43395               1              58.64  20.4               1       0
# 43396               1             213.61  55.4               0       0
# 43397               1              91.94  28.9               0       0
# 43398               1              99.16  33.2               1       0
# 43399               1              79.48  20.6               1       0
#
# [41836 rows x 11 columns]

# %%
#corr of the 
Cerebral_Stroke.corr()
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000 -0.032042      0.022068       0.079882
# age               -0.032042  1.000000      0.268915       0.243119
# hypertension       0.022068  0.268915      1.000000       0.121551
# heart_disease      0.079882  0.243119      0.121551       1.000000
# ever_married      -0.034740  0.694558      0.173040       0.123941
# work_type          0.067270 -0.371445     -0.060534      -0.021341
# Residence_type     0.003375  0.000888     -0.000661      -0.003928
# avg_glucose_level  0.032122  0.232051      0.158101       0.143226
# bmi               -0.021649  0.368386      0.158677       0.059931
# smoking_status    -0.010193 -0.115379     -0.033801      -0.033904
# stroke             0.009772  0.147750      0.079379       0.110479
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                -0.034740   0.067270        0.003375           0.032122
# age                    0.694558  -0.371445        0.000888           0.232051
# hypertension           0.173040  -0.060534       -0.000661           0.158101
# heart_disease          0.123941  -0.021341       -0.003928           0.143226
# ever_married           1.000000  -0.362888        0.004836           0.147977
# work_type             -0.362888   1.000000       -0.003113          -0.056386
# Residence_type         0.004836  -0.003113        1.000000          -0.000500
# avg_glucose_level      0.147977  -0.056386       -0.000500           1.000000
# bmi                    0.349754  -0.330460       -0.003360           0.192110
# smoking_status        -0.050223  -0.012213        0.010171          -0.035923
# stroke                 0.066865  -0.011839        0.002490           0.077132
#
#                         bmi  smoking_status    stroke
# gender            -0.021649       -0.010193  0.009772
# age                0.368386       -0.115379  0.147750
# hypertension       0.158677       -0.033801  0.079379
# heart_disease      0.059931       -0.033904  0.110479
# ever_married       0.349754       -0.050223  0.066865
# work_type         -0.330460       -0.012213 -0.011839
# Residence_type    -0.003360        0.010171  0.002490
# avg_glucose_level  0.192110       -0.035923  0.077132
# bmi                1.000000       -0.037654  0.022188
# smoking_status    -0.037654        1.000000 -0.019172
# stroke             0.022188       -0.019172  1.000000

# %%
plt.figure(figsize=(18,10))
sns.heatmap(Cerebral_Stroke.corr(),annot=True,fmt='.2',cmap="Greys")
plt.show()

# %% [markdown]
# #### Dummy Variables

# %%
dummy_data=pd.get_dummies(Cerebral_Stroke,columns={"gender","ever_married","work_type",
                                                   "Residence_type","smoking_status"},drop_first=True)

# %%
#checking the correlation of the new dataset
plt.figure(figsize=(12,8))
sns.heatmap(dummy_data.corr(),fmt='.2',cbar=False,cmap="RdPu_r")
plt.show()

# %%
dummy_data.head()
# Out:
#     age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# 0   3.0           0.0            0.0              95.12  18.0       0
# 1  58.0           1.0            0.0              87.96  39.2       0
# 2   8.0           0.0            0.0             110.89  17.6       0
# 3  70.0           0.0            0.0              69.04  35.9       0
# 4  14.0           0.0            0.0             161.28  19.1       0
#
#    gender_1  gender_2  Residence_type_1  smoking_status_1  smoking_status_2  \
# 0         1         0                 0                 1                 0
# 1         1         0                 1                 1                 0
# 2         0         0                 1                 1                 0
# 3         0         0                 0                 0                 0
# 4         1         0                 0                 1                 0
#
#    ever_married_1  work_type_1  work_type_2  work_type_3  work_type_4
# 0               0            0            0            0            1
# 1               1            0            1            0            0
# 2               0            0            1            0            0
# 3               1            0            1            0            0
# 4               0            1            0            0            0

# %%
da=dummy_data.copy()

# %% [markdown]
# ## Train and Test Data Split

# %%
x = da.drop(['stroke'], axis=1)
y = da['stroke']
# Splitting the data into train and test
X_train,X_test,y_train,y_test=train_test_split(x, y, train_size=0.8, stratify = y, random_state=100)

# %%
y_train.shape, y_test.shape
# Out:
# ((33468,), (8368,))

# %%
y_train.value_counts()/len(y_train)
# Out:
# 0    0.984642
# 1    0.015358
# Name: stroke, dtype: float64

# %%
    y_test.value_counts()/len(y_test)
# Out:
# 0    0.984704
# 1    0.015296
# Name: stroke, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
Scaler_X = StandardScaler()
X_train = Scaler_X.fit_transform(X_train)
X_test = Scaler_X.transform(X_test)

# %% [markdown]
# # Resampling techniques to handel class imbalance

# %% [markdown]
# ## 1. Oversampling

# %% [markdown]
# ### 1.1 Random Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using Random Over Sampling
ros = RandomOverSampler()
X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)

counter = Counter(y_train_ros)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 514})
# After Counter({0: 32954, 1: 32954})

# %% [markdown]
# ### 1.2 SMOTE

# %%
#K Means SMOTE
#library for perfroming SMOTE
from imblearn.over_sampling import SMOTE

# %%
# counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using SMOTE
smt = SMOTE()
X_train_sm, y_train_sm = smt.fit_resample(X_train, y_train)

counter = Counter(y_train_sm)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 32954})
# After Counter({0: 32954, 1: 32954})

# %% [markdown]
# ### 1.3 ADASYN

# %%
from imblearn.over_sampling import ADASYN

counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using ADASYN
ada = ADASYN()
X_train_ada, y_train_ada = ada.fit_resample(X_train, y_train)

counter = Counter(y_train_ada)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 514})
# After Counter({0: 32954, 1: 32787})

# %% [markdown]
# ## 2. Undersampling

# %% [markdown]
# ### 2.1 Random Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler

counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using Random Under Sampling
rus = RandomUnderSampler()
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

counter = Counter(y_train_rus)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 514})
# After Counter({0: 514, 1: 514})

# %% [markdown]
# ### 2.2 Tomek Links

# %%
from imblearn.under_sampling import TomekLinks

counter = Counter(y_train)
print('Before',counter)
# undersampling the train dataset using TomekLinks
toml = TomekLinks()
X_train_toml, y_train_toml = toml.fit_resample(X_train, y_train)

counter = Counter(y_train_toml)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 514})
# After Counter({0: 32683, 1: 514})

# %% [markdown]
# ### 2.3 Near Miss

# %%
from imblearn.under_sampling import NearMiss

counter = Counter(y_train)
print('Before',counter)
# undersampling the train dataset using Near Miss
nm = NearMiss()
X_train_nm, y_train_nm = nm.fit_resample(X_train, y_train)

counter = Counter(y_train_nm)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 514})
# After Counter({0: 514, 1: 514})

# %% [markdown]
# ## 3. Hybrid Techniques

# %% [markdown]
# ### 3.1 SMOTE + Tomek Links

# %%
from imblearn.combine import SMOTETomek

counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using SMOTE + Tomek
smtom = SMOTETomek(random_state=139)
X_train_smtom, y_train_smtom = smtom.fit_resample(X_train, y_train)

counter = Counter(y_train_smtom)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 514})
# After Counter({0: 32780, 1: 32780})

# %% [markdown]
# ### 3.2 SMOTE + ENN

# %%
from imblearn.combine import SMOTEENN

counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using SMOTE + ENN
smenn = SMOTEENN()
X_train_smenn, y_train_smenn = smenn.fit_resample(X_train, y_train)

counter = Counter(y_train_smenn)
print('After',counter)
# Out:
# Before Counter({0: 32954, 1: 514})
# After Counter({1: 31562, 0: 29312})

# %% [markdown]
# # Visualizing Resampled Data

# %%
from sklearn.datasets import make_classification
X, Y = make_classification(n_samples=20000, n_features=2, n_informative=2,
                            n_redundant=0, n_repeated=0, n_classes=2,
                            n_clusters_per_class=1,
                            weights=[0.95, 0.05],
                            class_sep=0.8, random_state=100)
X1, X2 = list(), list()
for i, j in enumerate(X):
    X1.append(j[0])
    X2.append(j[1])
df = pd.DataFrame({'X1':X1, 'X2':X2, 'Y':Y})
pal = sns.color_palette('tab10')
print(pal.as_hex())
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
#sns.set_palette('icefire')
sns.set_palette(['#55a3cd', '#9c2f45'])
sns.palplot(sns.color_palette())

# %% [markdown]
# # Imbalanced Data

# %%
plt.figure(figsize=(10,6),dpi=100)

sns.despine(left=True)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df)
plt.show()

# %%
df['Y'].value_counts()
# Out:
# 0    18909
# 1     1091
# Name: Y, dtype: int64

# %%
x = df.drop('Y', axis=1)
y = df['Y']

# %% [markdown]
# # With Resampling Techniques

# %%
counter = Counter(y)
ros = RandomOverSampler()
X_train1, y_train1 = ros.fit_resample(x, y)
counter = Counter(y_train1)
df_ros = X_train1.copy()
df_ros['Y'] = y_train1

counter = Counter(y)
smt = SMOTE()
X_train1, y_train1 = smt.fit_resample(x, y)
counter = Counter(y_train1)
df_sm = X_train1.copy()
df_sm['Y'] = y_train1

counter = Counter(y)
ada = ADASYN()
X_train1, y_train1 = ada.fit_resample(x, y)
counter = Counter(y_train1)
df_ada = X_train1.copy()
df_ada['Y'] = y_train1

counter = Counter(y)
rus = RandomUnderSampler()
X_train1, y_train1 = rus.fit_resample(x, y)
counter = Counter(y_train1)
df_rus = X_train1.copy()
df_rus['Y'] = y_train1

counter = Counter(y)
toml = TomekLinks()
X_train1, y_train1 = toml.fit_resample(x, y)
counter = Counter(y_train1)
df_toml = X_train1.copy()
df_toml['Y'] = y_train1

counter = Counter(y)
nm = NearMiss()
X_train1, y_train1 = nm.fit_resample(x, y)
counter = Counter(y_train1)
df_nm = X_train1.copy()
df_nm['Y'] = y_train1

counter = Counter(y)
smtom = SMOTETomek()
X_train1, y_train1 = smtom.fit_resample(x, y)
counter = Counter(y_train1)
df_smtom = X_train1.copy()
df_smtom['Y'] = y_train1

counter = Counter(y)
smenn = SMOTEENN()
X_train1, y_train1 = smenn.fit_resample(x, y)
counter = Counter(y_train1)
df_smenn = X_train1.copy()
df_smenn['Y'] = y_train1

# %%
f, axes = plt.subplots(4,2,figsize=(10, 15), dpi=100)
sns.despine()
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_ros, ax=axes[0,0])
axes[0,0].set_title('Resampling with Random Over Sampling', fontsize=14)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_sm, ax=axes[0,1])
axes[0,1].set_title('Resampling with SMOTE', fontsize=14)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_ada, ax=axes[1,0])
axes[1,0].set_title('Resampling with ADASYN', fontsize=14)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_rus, ax=axes[1,1])
axes[1,1].set_title('Resampling with Random Under Sampling', fontsize=14)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_toml, ax=axes[2,0])
axes[2,0].set_title('Resampling with Tomek Links', fontsize=14)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_nm, ax=axes[2,1])
axes[2,1].set_title('Resampling with Near Miss', fontsize=14)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_smtom, ax=axes[3,0])
axes[3,0].set_title('Resampling with SMOTE + Tomek Links', fontsize=14)
sns.scatterplot(x='X1', y='X2', hue = 'Y', data=df_smenn, ax=axes[3,1])
axes[3,1].set_title('Resampling with SMOTE + ENN', fontsize=14)
plt.setp(axes, yticks=[])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Building Models

# %%
model = list()
resample = list()
precision = list()
recall = list()
F1score = list()
AUCROC = list()

from sklearn.datasets import make_classification
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report, precision_recall_curve
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV, RandomizedSearchCV

# %%
def test_eval(clf_model, X_test, y_test, algo=None, sampling=None):
    # Test set prediction
    y_prob=clf_model.predict_proba(X_test)
    y_pred=clf_model.predict(X_test)

    print('Confusion Matrix')
    print('='*60)
    plot_confusion_matrix(clf_model, X_test, y_test)  
    plt.show()
    #print(confusion_matrix(y_test,y_pred),"\n")
    print('Classification Report')
    print('='*60)
    print(classification_report(y_test,y_pred),"\n")
    print('AUC-ROC')
    print('='*60)
    print(roc_auc_score(y_test, y_prob[:,1]))
          
    model.append(algo)
    precision.append(precision_score(y_test,y_pred))
    recall.append(recall_score(y_test,y_pred))
    F1score.append(f1_score(y_test,y_pred))
    AUCROC.append(roc_auc_score(y_test, y_prob[:,1]))
    resample.append(sampling)

# %% [markdown]
# # Model-1: Logistic Regression

# %% [markdown]
# # 1. Original Unsampled Data

# %%
log_model=LogisticRegression()

params={'C':np.logspace(-10, 1, 15),'class_weight':[None,'balanced'],'penalty':['l1','l2']}

cv = StratifiedKFold(n_splits=5, random_state=100, shuffle=True)

# Create grid search using 5-fold cross validation
clf_LR = GridSearchCV(log_model, params, cv=cv, scoring='roc_auc', n_jobs=-1)
clf_LR.fit(X_train, y_train)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.04393970560760786)

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'actual')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8240
#            1       0.00      0.00      0.00       128
#
#     accuracy                           0.98      8368
#    macro avg       0.49      0.50      0.50      8368
# weighted avg       0.97      0.98      0.98      8368
#
#
# AUC-ROC
# ============================================================
# 0.8667930825242718

# %% [markdown]
# # 2. Random Over Resampling

# %%
clf_LR.fit(X_train_ros, y_train_ros)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.007196856730011514, class_weight='balanced')

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'random os')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.85      8240
#            1       0.05      0.83      0.09       128
#
#     accuracy                           0.75      8368
#    macro avg       0.52      0.79      0.47      8368
# weighted avg       0.98      0.75      0.84      8368
#
#
# AUC-ROC
# ============================================================
# 0.8646778291868932

# %% [markdown]
# ### 3. SMOTE Resampling

# %%
clf_LR.fit(X_train_sm, y_train_sm)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.0011787686347935866, class_weight='balanced')

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'smote')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86      8240
#            1       0.05      0.83      0.09       128
#
#     accuracy                           0.75      8368
#    macro avg       0.52      0.79      0.47      8368
# weighted avg       0.98      0.75      0.84      8368
#
#
# AUC-ROC
# ============================================================
# 0.8665826001213592

# %% [markdown]
# ### 4. ADASYN Resampling

# %%
clf_LR.fit(X_train_ada, y_train_ada)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.0011787686347935866)

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'adasyn')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.85      8240
#            1       0.05      0.83      0.09       128
#
#     accuracy                           0.75      8368
#    macro avg       0.52      0.79      0.47      8368
# weighted avg       0.98      0.75      0.84      8368
#
#
# AUC-ROC
# ============================================================
# 0.8664555521844661

# %% [markdown]
# ### 5. Random Under Resampling

# %%
clf_LR.fit(X_train_rus, y_train_rus)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.26826957952797276)

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'random us')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.85      8240
#            1       0.05      0.82      0.09       128
#
#     accuracy                           0.75      8368
#    macro avg       0.52      0.78      0.47      8368
# weighted avg       0.98      0.75      0.84      8368
#
#
# AUC-ROC
# ============================================================
# 0.8618856189320387

# %% [markdown]
# ### 6. Tomek Links Resampling

# %%
clf_LR.fit(X_train_toml, y_train_toml)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.007196856730011514, class_weight='balanced')

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'tomek links')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85      8240
#            1       0.05      0.83      0.09       128
#
#     accuracy                           0.75      8368
#    macro avg       0.52      0.79      0.47      8368
# weighted avg       0.98      0.75      0.84      8368
#
#
# AUC-ROC
# ============================================================
# 0.8647005840412623

# %% [markdown]
# ### 7. Near Miss Resampling

# %%
clf_LR.fit(X_train_nm, y_train_nm)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=10.0)

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'near miss')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.32      0.48      8240
#            1       0.02      0.74      0.03       128
#
#     accuracy                           0.32      8368
#    macro avg       0.50      0.53      0.26      8368
# weighted avg       0.97      0.32      0.47      8368
#
#
# AUC-ROC
# ============================================================
# 0.5043158373786407

# %% [markdown]
# ### 8. SMOTE + Tomek Resampling

# %%
clf_LR.fit(X_train_smtom, y_train_smtom)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.0011787686347935866)

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'smote+tomek')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86      8240
#            1       0.05      0.82      0.09       128
#
#     accuracy                           0.75      8368
#    macro avg       0.52      0.79      0.47      8368
# weighted avg       0.98      0.75      0.84      8368
#
#
# AUC-ROC
# ============================================================
# 0.8668404884708737

# %% [markdown]
# ### 9. SMOTE + ENN Resampling

# %%
clf_LR.fit(X_train_smenn, y_train_smenn)
clf_LR.best_estimator_
# Out:
# LogisticRegression(C=0.007196856730011514, class_weight='balanced')

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression', 'smote+enn')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85      8240
#            1       0.05      0.84      0.09       128
#
#     accuracy                           0.74      8368
#    macro avg       0.52      0.79      0.47      8368
# weighted avg       0.98      0.74      0.84      8368
#
#
# AUC-ROC
# ============================================================
# 0.8672301653519418

# %% [markdown]
# # Model-2: Decision Tree

# %%
estimators = [2,10,30,50,100]
# Maximum number of depth in each tree:
max_depth = [i for i in range(5,16,2)]
# Minimum number of samples to consider to split a node:
min_samples_split = [2, 5, 10, 15, 20, 50, 100]
# Minimum number of samples to consider at each leaf node:
min_samples_leaf = [1, 2, 5]

# %% [markdown]
# ### 1. Original Unsampled Data

# %%
tree_model = DecisionTreeClassifier()

tree_param_grid = { 
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf
}

clf_DT = RandomizedSearchCV(tree_model, tree_param_grid, cv=cv, scoring='roc_auc', n_jobs=-1, verbose=2)
clf_DT.fit(X_train, y_train)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    2.7s finished
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=5, min_samples_split=15)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'actual')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8240
#            1       0.00      0.00      0.00       128
#
#     accuracy                           0.98      8368
#    macro avg       0.49      0.50      0.50      8368
# weighted avg       0.97      0.98      0.98      8368
#
#
# AUC-ROC
# ============================================================
# 0.7927388311589806

# %% [markdown]
# ### 2. Random Over Resampling

# %%
clf_DT.fit(X_train_ros, y_train_ros)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    3.8s finished
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=2, min_samples_split=100)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'random os')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95      8240
#            1       0.05      0.26      0.08       128
#
#     accuracy                           0.91      8368
#    macro avg       0.52      0.59      0.51      8368
# weighted avg       0.97      0.91      0.94      8368
#
#
# AUC-ROC
# ============================================================
# 0.5866884101941747

# %% [markdown]
# ### 3. SMOTE Resampling

# %%
clf_DT.fit(X_train_sm, y_train_sm)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.9s finished
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=2, min_samples_split=50)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'smote')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      8240
#            1       0.07      0.41      0.11       128
#
#     accuracy                           0.90      8368
#    macro avg       0.53      0.66      0.53      8368
# weighted avg       0.98      0.90      0.94      8368
#
#
# AUC-ROC
# ============================================================
# 0.7332367832220874

# %% [markdown]
# ### 4. ADASYN Resampling

# %%
clf_DT.fit(X_train_ada, y_train_ada)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.7s finished
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=5, min_samples_split=20)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'adasyn')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.95      8240
#            1       0.06      0.40      0.11       128
#
#     accuracy                           0.90      8368
#    macro avg       0.53      0.65      0.53      8368
# weighted avg       0.98      0.90      0.93      8368
#
#
# AUC-ROC
# ============================================================
# 0.6883983426881067

# %% [markdown]
# ### 5. Random Under Resampling

# %%
clf_DT.fit(X_train_rus, y_train_rus)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.2s finished
# DecisionTreeClassifier(max_depth=5, min_samples_split=100)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'random us')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.72      0.84      8240
#            1       0.04      0.81      0.08       128
#
#     accuracy                           0.72      8368
#    macro avg       0.52      0.77      0.46      8368
# weighted avg       0.98      0.72      0.83      8368
#
#
# AUC-ROC
# ============================================================
# 0.8400973718143203

# %% [markdown]
# ### 6. Tomek Links Resampling

# %%
clf_DT.fit(X_train_toml, y_train_toml)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    1.8s finished
# DecisionTreeClassifier(max_depth=5, min_samples_split=20)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'tomek links')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8240
#            1       0.00      0.00      0.00       128
#
#     accuracy                           0.98      8368
#    macro avg       0.49      0.50      0.50      8368
# weighted avg       0.97      0.98      0.98      8368
#
#
# AUC-ROC
# ============================================================
# 0.853463952518204

# %% [markdown]
# ### 7. Near Miss Resampling

# %%
clf_DT.fit(X_train_nm, y_train_nm)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.1s finished
# DecisionTreeClassifier(max_depth=13, min_samples_split=50)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'near miss')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.28      0.44      8240
#            1       0.02      0.77      0.03       128
#
#     accuracy                           0.29      8368
#    macro avg       0.50      0.52      0.23      8368
# weighted avg       0.97      0.29      0.43      8368
#
#
# AUC-ROC
# ============================================================
# 0.5100130840412622

# %% [markdown]
# ### 8. SMOTE + Tomek Resampling

# %%
clf_DT.fit(X_train_smtom, y_train_smtom)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.1s finished
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=2, min_samples_split=5)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'smote+tomek')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      8240
#            1       0.06      0.39      0.11       128
#
#     accuracy                           0.90      8368
#    macro avg       0.53      0.65      0.53      8368
# weighted avg       0.98      0.90      0.94      8368
#
#
# AUC-ROC
# ============================================================
# 0.6731407387742718

# %% [markdown]
# ### 9. SMOTE + ENN Resampling

# %%
clf_DT.fit(X_train_smenn, y_train_smenn)
clf_DT.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    5.0s finished
# DecisionTreeClassifier(max_depth=15, min_samples_split=50)

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree', 'smote+enn')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.93      8240
#            1       0.05      0.36      0.08       128
#
#     accuracy                           0.88      8368
#    macro avg       0.52      0.62      0.51      8368
# weighted avg       0.97      0.88      0.92      8368
#
#
# AUC-ROC
# ============================================================
# 0.717435433100728

# %% [markdown]
# # Model-3: Random Forest

# %% [markdown]
# ### 1. Original Unsampled Data

# %%
rf_model = RandomForestClassifier()

rf_params={'n_estimators':estimators,
           'max_depth':max_depth,
           'min_samples_split':min_samples_split}

clf_RF = RandomizedSearchCV(rf_model, rf_params, cv=cv, scoring='roc_auc', n_jobs=-1, n_iter=20, verbose=2)
clf_RF.fit(X_train, y_train)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   26.8s finished
# RandomForestClassifier(max_depth=7, min_samples_split=5)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'actual')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8240
#            1       0.00      0.00      0.00       128
#
#     accuracy                           0.98      8368
#    macro avg       0.49      0.50      0.50      8368
# weighted avg       0.97      0.98      0.98      8368
#
#
# AUC-ROC
# ============================================================
# 0.8554573725728155

# %% [markdown]
# ### 2. Random Over Resampling

# %%
clf_RF.fit(X_train_ros, y_train_ros)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.3min finished
# RandomForestClassifier(max_depth=15, min_samples_split=15)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'random os')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      8240
#            1       0.04      0.07      0.05       128
#
#     accuracy                           0.96      8368
#    macro avg       0.51      0.52      0.52      8368
# weighted avg       0.97      0.96      0.97      8368
#
#
# AUC-ROC
# ============================================================
# 0.7808821298543689

# %% [markdown]
# ### 3. SMOTE Resampling

# %%
clf_RF.fit(X_train_sm, y_train_sm)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.3min finished
# RandomForestClassifier(max_depth=15, n_estimators=50)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'smote')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      8240
#            1       0.05      0.34      0.09       128
#
#     accuracy                           0.89      8368
#    macro avg       0.52      0.62      0.52      8368
# weighted avg       0.97      0.89      0.93      8368
#
#
# AUC-ROC
# ============================================================
# 0.7839089995449029

# %% [markdown]
# ### 4. ADASYN Resampling

# %%
clf_RF.fit(X_train_ada, y_train_ada)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   47.9s finished
# RandomForestClassifier(max_depth=15, min_samples_split=10, n_estimators=30)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'adasyn')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      8240
#            1       0.05      0.34      0.09       128
#
#     accuracy                           0.89      8368
#    macro avg       0.52      0.62      0.51      8368
# weighted avg       0.97      0.89      0.93      8368
#
#
# AUC-ROC
# ============================================================
# 0.7878128792475728

# %% [markdown]
# ### 5. Random Under Resampling

# %%
clf_RF.fit(X_train_rus, y_train_rus)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.9s finished
# RandomForestClassifier(max_depth=7, min_samples_split=10, n_estimators=10)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'random us')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83      8240
#            1       0.04      0.83      0.08       128
#
#     accuracy                           0.71      8368
#    macro avg       0.52      0.77      0.45      8368
# weighted avg       0.98      0.71      0.82      8368
#
#
# AUC-ROC
# ============================================================
# 0.8508338706007282

# %% [markdown]
# ### 6. Tomek Links Resampling

# %%
clf_RF.fit(X_train_toml, y_train_toml)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   23.5s finished
# RandomForestClassifier(max_depth=9, min_samples_split=100)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'tomek links')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8240
#            1       0.00      0.00      0.00       128
#
#     accuracy                           0.98      8368
#    macro avg       0.49      0.50      0.50      8368
# weighted avg       0.97      0.98      0.98      8368
#
#
# AUC-ROC
# ============================================================
# 0.857225614381068

# %% [markdown]
# ### 7. Near Miss Resampling

# %%
clf_RF.fit(X_train_nm, y_train_nm)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  85 out of 100 | elapsed:    2.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.3s finished
# RandomForestClassifier(max_depth=11, min_samples_split=20)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'near miss')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.12      0.21      8240
#            1       0.02      0.88      0.03       128
#
#     accuracy                           0.13      8368
#    macro avg       0.50      0.50      0.12      8368
# weighted avg       0.97      0.13      0.21      8368
#
#
# AUC-ROC
# ============================================================
# 0.5303331689927184

# %% [markdown]
# ### 8. SMOTE + Tomek Resampling

# %%
clf_RF.fit(X_train_smtom, y_train_smtom)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.1min finished
# RandomForestClassifier(max_depth=15, min_samples_split=50)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'smote+tomek')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94      8240
#            1       0.05      0.38      0.09       128
#
#     accuracy                           0.88      8368
#    macro avg       0.52      0.63      0.51      8368
# weighted avg       0.97      0.88      0.92      8368
#
#
# AUC-ROC
# ============================================================
# 0.8117358161407766

# %% [markdown]
# ### 9. SMOTE + ENN Resampling

# %%
clf_RF.fit(X_train_smenn, y_train_smenn)
clf_RF.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.4min finished
# RandomForestClassifier(max_depth=15, n_estimators=50)

# %%
test_eval(clf_RF, X_test, y_test, 'Random Forest', 'smote+enn')
# Out:
# Confusion Matrix
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93      8240
#            1       0.05      0.41      0.09       128
#
#     accuracy                           0.88      8368
#    macro avg       0.52      0.65      0.51      8368
# weighted avg       0.98      0.88      0.92      8368
#
#
# AUC-ROC
# ============================================================
# 0.7975623862257282

# %% [markdown]
# # Comparitive Analysis

# %%
clf_eval_df = pd.DataFrame({'model':model,
                            'resample':resample,
                            'precision':precision,
                            'recall':recall,
                            'f1-score':F1score,
                            'AUC-ROC':AUCROC})

# %%
clf_eval_df
# Out:
#                   model     resample  precision    recall  f1-score   AUC-ROC
# 0   Logistic Regression       actual   0.000000  0.000000  0.000000  0.866793
# 1   Logistic Regression    random os   0.048138  0.828125  0.090987  0.864678
# 2   Logistic Regression        smote   0.049097  0.828125  0.092698  0.866583
# 3   Logistic Regression       adasyn   0.048424  0.828125  0.091498  0.866456
# 4   Logistic Regression    random us   0.048077  0.820312  0.090830  0.861886
# 5   Logistic Regression  tomek links   0.047920  0.828125  0.090598  0.864701
# 6   Logistic Regression    near miss   0.016553  0.742188  0.032385  0.504316
# 7   Logistic Regression  smote+tomek   0.048656  0.820312  0.091864  0.866840
# 8   Logistic Regression    smote+enn   0.047640  0.835938  0.090143  0.867230
# 9         Decision Tree       actual   0.000000  0.000000  0.000000  0.792739
# 10        Decision Tree    random os   0.045392  0.257812  0.077193  0.586688
# 11        Decision Tree        smote   0.066838  0.406250  0.114790  0.733237
# 12        Decision Tree       adasyn   0.061151  0.398438  0.106029  0.688398
# 13        Decision Tree    random us   0.043588  0.812500  0.082737  0.840097
# 14        Decision Tree  tomek links   0.000000  0.000000  0.000000  0.853464
# 15        Decision Tree    near miss   0.016231  0.765625  0.031787  0.510013
# 16        Decision Tree  smote+tomek   0.063052  0.390625  0.108578  0.673141
# 17        Decision Tree    smote+enn   0.046748  0.359375  0.082734  0.717435
# 18        Random Forest       actual   0.000000  0.000000  0.000000  0.855457
# 19        Random Forest    random os   0.043269  0.070312  0.053571  0.780882
# 20        Random Forest        smote   0.051704  0.343750  0.089888  0.783909
# 21        Random Forest       adasyn   0.048753  0.335938  0.085149  0.787813
# 22        Random Forest    random us   0.042315  0.828125  0.080517  0.850834
# 23        Random Forest  tomek links   0.000000  0.000000  0.000000  0.857226
# 24        Random Forest    near miss   0.015353  0.882812  0.030182  0.530333
# 25        Random Forest  smote+tomek   0.050901  0.375000  0.089636  0.811736
# 26        Random Forest    smote+enn   0.051859  0.414062  0.092174  0.797562

# %%
sns.set(font_scale=1.2)
#sns.palplot(sns.color_palette())
g = sns.FacetGrid(clf_eval_df, col="model", height=5)
g.map(sns.barplot, "resample", "recall", palette='twilight', order=["actual", "random os", "smote", "adasyn", "random us", "tomek links", "near miss", "smote+tomek", "smote+enn"])
g.set_xticklabels(rotation=90)
g.set_xlabels(' ', fontsize=14)
g.set_ylabels('Recall', fontsize=14)

# %%
sns.set(font_scale=1.2)
#sns.palplot(sns.color_palette())
g = sns.FacetGrid(clf_eval_df, col="model", height=5)
g.map(sns.barplot, "resample", "f1-score", palette='icefire', order=["actual", "random os", "smote", "adasyn", "random us", "tomek links", "near miss", "smote+tomek", "smote+enn"])
g.set_xticklabels(rotation=90)
g.set_xlabels(' ', fontsize=14)
g.set_ylabels('f1-score', fontsize=14)

# %%
sns.set(font_scale=1.2)
#sns.palplot(sns.color_palette())
g = sns.FacetGrid(clf_eval_df, col="model", height=5)
g.map(sns.barplot, "resample", "AUC-ROC", palette='Spectral', order=["actual", "random os", "smote", "adasyn", "random us", "tomek links", "near miss", "smote+tomek", "smote+enn"])
g.set_xticklabels(rotation=90)
g.set_xlabels(' ', fontsize=14)
g.set_ylabels('AUC-ROC', fontsize=14)

# %%
sns.set(font_scale=1.2)
#sns.palplot(sns.color_palette())
g = sns.FacetGrid(clf_eval_df, col="model", height=5)
g.map(sns.barplot, "resample", "precision", palette='cubehelix', order=["actual", "random os", "smote", "adasyn", "random us", "tomek links", "near miss", "smote+tomek", "smote+enn"])
g.set_xticklabels(rotation=90)
g.set_xlabels(' ', fontsize=14)
g.set_ylabels('precision', fontsize=14)
