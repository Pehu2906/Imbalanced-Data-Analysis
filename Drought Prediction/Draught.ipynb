# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
drought_df = pd.read_csv("C:\\Users\\study\\Downloads\\train_timeseries.csv")
drought_df
# Out:
#            fips        date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  \
# 0          1001  2000-01-01     0.22  100.51   9.65  14.74   13.51   13.51
# 1          1001  2000-01-02     0.20  100.55  10.42  16.69   14.71   14.71
# 2          1001  2000-01-03     3.65  100.15  11.76  18.49   16.52   16.52
# 3          1001  2000-01-04    15.95  100.29   6.42  11.40    6.09    6.10
# 4          1001  2000-01-05     0.00  101.15   2.95   3.86   -3.29   -3.20
# ...         ...         ...      ...     ...    ...    ...     ...     ...
# 19300675  56043  2016-12-27     0.16   82.88   1.63  -7.97  -13.49  -12.81
# 19300676  56043  2016-12-28     0.02   83.33   1.41  -8.71  -14.10  -13.84
# 19300677  56043  2016-12-29     0.00   83.75   1.59  -7.96  -13.30  -13.03
# 19300678  56043  2016-12-30     1.22   82.49   2.63  -2.94   -7.40   -7.33
# 19300679  56043  2016-12-31     0.44   82.19   1.75  -7.56  -11.98  -11.82
#
# ...

# %%
drought_df.describe(include='all')
# Out:
#                 fips        date       PRECTOT            PS          QV2M  \
# count   1.930068e+07    19300680  1.930068e+07  1.930068e+07  1.930068e+07
# unique           NaN        6210           NaN           NaN           NaN
# top              NaN  2003-11-22           NaN           NaN           NaN
# freq             NaN        3108           NaN           NaN           NaN
# mean    3.067038e+04         NaN  2.644145e+00  9.665578e+01  7.816178e+00
# std     1.497911e+04         NaN  6.226305e+00  5.447994e+00  4.694305e+00
# min     1.001000e+03         NaN  0.000000e+00  6.612000e+01  1.200000e-01
# 25%     1.904450e+04         NaN  0.000000e+00  9.584000e+01  3.780000e+00
# 50%     2.921200e+04         NaN  1.800000e-01  9.830000e+01  6.840000e+00
# 75%     4.600750e+04         NaN  2.160000e+00  9.996000e+01  1.135000e+01
# max     5.604300e+04         NaN  2.345900e+02  1.043200e+02  2.292000e+01
#
# ...

# %%
drought_df.info()

# %%
drought_df.nunique()

# %%
#Calculating count of Drought vs No Drought cases
